# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error

# Showing values upto 2 decimal places
pd.set_option('display.float_format', '{:.2f}'.format)

path = '/Users/umeshnagar/Downloads/Assessment 2/'
# Load datasets
train_df = pd.read_csv(path + "train.csv", parse_dates=["timestamp"])
test_df = pd.read_csv(path + "test.csv", parse_dates=["timestamp"])

# %%
train_df.head()
# Out:
#             timestamp  energy_output  irradiance_global_index  \
# 0 2024-10-01 00:00:00           0.00                     0.00
# 1 2024-10-01 01:00:00           0.00                     0.00
# 2 2024-10-01 02:00:00           0.00                     0.00
# 3 2024-10-01 03:00:00           0.00                     0.00
# 4 2024-10-01 04:00:00           0.00                     0.00
#
#    irradiance_global_reference  irradiance_horizontal  module_temperature_1  \
# 0                         0.00                   0.00                 22.14
# 1                         0.00                   0.00                 21.90
# 2                         0.00                   0.00                 22.54
# 3                         0.00                   0.00                 22.69
# 4                         0.00                   0.00                 23.16
#
#    module_temperature_2  module_temperature_3  wind_direction  \
# 0                 21.77                 21.89          166.49
# 1                 21.49                 21.65          257.27
# 2                 22.29                 22.32          212.57
# 3                 22.51                 22.48          157.93
# 4                 22.86                 22.86          142.27
#
#    relative_humidity  ...  incident_radiation_1  incident_radiation_2  \
# 0             100.00  ...                  0.00                   NaN
# 1             100.00  ...                  0.00                   NaN
# 2             100.00  ...                  0.00                   NaN
# 3             100.00  ...                  0.00                   NaN
# 4             100.00  ...                  0.00                   NaN
#
#    incident_radiation_4  incident_radiation_3  reflected_radiation_1  \
# 0                  0.00                   NaN                   0.00
# 1                  0.00                   NaN                   0.00
# 2                  0.00                   NaN                   0.00
# 3                  0.00                   NaN                   0.00
# 4                  0.00                   NaN                   0.00
#
#    reflected_radiation_2  reflected_radiation_4  reflected_radiation_3  \
# 0                    NaN                   0.00                    NaN
# 1                    NaN                   0.00                    NaN
# 2                    NaN                   0.00                    NaN
# 3                    NaN                   0.00                    NaN
# 4                    NaN                   0.00                    NaN
#
#    ambient_temperature  wind_speed
# 0                23.45        0.00
# 1                23.22        0.00
# 2                23.30        0.00
# 3                23.35        1.83
# 4                23.51        0.00
#
# [5 rows x 23 columns]

# %%
def add_cyclic_feature(df):
    df['hour'] = df['timestamp'].dt.hour  

    # Apply sine and cosine transformations
    df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)
    
    return df

train_df = add_cyclic_feature(train_df)
test_df = add_cyclic_feature(test_df)

# %%
train_df.head()
# Out:
#             timestamp  energy_output  irradiance_global_index  \
# 0 2024-10-01 00:00:00           0.00                     0.00
# 1 2024-10-01 01:00:00           0.00                     0.00
# 2 2024-10-01 02:00:00           0.00                     0.00
# 3 2024-10-01 03:00:00           0.00                     0.00
# 4 2024-10-01 04:00:00           0.00                     0.00
#
#    irradiance_global_reference  irradiance_horizontal  module_temperature_1  \
# 0                         0.00                   0.00                 22.14
# 1                         0.00                   0.00                 21.90
# 2                         0.00                   0.00                 22.54
# 3                         0.00                   0.00                 22.69
# 4                         0.00                   0.00                 23.16
#
#    module_temperature_2  module_temperature_3  wind_direction  \
# 0                 21.77                 21.89          166.49
# 1                 21.49                 21.65          257.27
# 2                 22.29                 22.32          212.57
# 3                 22.51                 22.48          157.93
# 4                 22.86                 22.86          142.27
#
#    relative_humidity  ...  incident_radiation_3  reflected_radiation_1  \
# 0             100.00  ...                   NaN                   0.00
# 1             100.00  ...                   NaN                   0.00
# 2             100.00  ...                   NaN                   0.00
# 3             100.00  ...                   NaN                   0.00
# 4             100.00  ...                   NaN                   0.00
#
#    reflected_radiation_2  reflected_radiation_4  reflected_radiation_3  \
# 0                    NaN                   0.00                    NaN
# 1                    NaN                   0.00                    NaN
# 2                    NaN                   0.00                    NaN
# 3                    NaN                   0.00                    NaN
# 4                    NaN                   0.00                    NaN
#
#    ambient_temperature  wind_speed  hour  hour_sin  hour_cos
# 0                23.45        0.00     0      0.00      1.00
# 1                23.22        0.00     1      0.26      0.97
# 2                23.30        0.00     2      0.50      0.87
# 3                23.35        1.83     3      0.71      0.71
# 4                23.51        0.00     4      0.87      0.50
#
# [5 rows x 26 columns]

# %%
def add_lag_features(df):
    # Creating Target Variables (1 to 6-hour ahead)
    for h in range(1, 7):  
        df[f'target_{h}'] = df["energy_output"].shift(h)

    # Drop NaN values caused by shifting
    df.dropna(inplace=True)
    df.drop('hour',axis = 1,inplace=True)
    return df

train_df = add_lag_features(train_df)

# %%
train_df.head()
# Out:
#                timestamp  energy_output  irradiance_global_index  \
# 830  2024-11-04 16:00:00       11244.00                   162.46
# 870  2024-11-06 08:00:00       48033.00                   677.28
# 877  2024-11-06 15:00:00        6675.00                   100.83
# 878  2024-11-06 16:00:00       12553.00                   171.66
# 1015 2024-11-12 09:00:00       38760.00                   452.80
#
#       irradiance_global_reference  irradiance_horizontal  \
# 830                         20.71                 134.27
# 870                         43.60                 503.01
# 877                         11.78                  82.60
# 878                         12.24                 106.15
# 1015                        35.92                 399.04
#
#       module_temperature_1  module_temperature_2  module_temperature_3  \
# 830                  34.58                 34.46                 34.10
# 870                  48.11                 43.22                 41.25
# 877                  29.84                 29.79                 29.76
# 878                  31.69                 30.48                 30.95
# 1015                 39.66                 38.28                 38.25
#
#       wind_direction  relative_humidity  ...  ambient_temperature  wind_speed  \
# 830           132.23              82.83  ...                28.89        2.50
# 870           181.39              95.22  ...                27.65        3.57
# 877           162.54              86.73  ...                27.92        3.25
# 878           221.32              97.76  ...                27.44        2.18
# 1015          120.79              91.37  ...                26.99        3.20
#
#       hour_sin  hour_cos  target_1  target_2  target_3  target_4  target_5  \
# 830      -0.87     -0.50  51366.00  62059.00  54025.00  47719.00  35348.00
# 870       0.87     -0.50  37260.00   6825.00     51.00      0.00      0.00
# 877      -0.71     -0.71  53954.00  38172.00  54366.00  58593.00  55180.00
# 878      -0.87     -0.50   6675.00  53954.00  38172.00  54366.00  58593.00
# 1015      0.71     -0.71  60171.00  18852.00   5193.00     61.00      0.00
#
#       target_6
# 830   20918.00
# 870       0.00
# 877   54721.00
# 878   55180.00
# 1015      0.00
#
# [5 rows x 31 columns]

# %%
def prepare_input(train_df, test_df):
    train_df = train_df.fillna(train_df.mean())
    test_df = test_df.fillna(test_df.mean())

    
    # Select Features (Exclude target variables)
    features = [col for col in train_df.columns if col not in ["timestamp", "energy_output"] + [f'target_{h}' for h in range(1, 7)]]

    # Prepare input variables
    X_train = train_df[features]
    X_test_eval = test_df[features]  # Use test set only for evaluation
    
     # Standardize features (not mandatory for xgboost)
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test_eval = scaler.transform(X_test_eval)
    
    return X_train, X_test_eval

X_train,  X_test_eval = prepare_input(train_df, test_df)

# %%
# Dictionary to store models & predictions
def prepar_output(df):
    models = {}
    predictions = pd.DataFrame({"timestamp": df["timestamp"], "month": df["timestamp"].dt.strftime("%Y-%m")})
    return predictions, models

predictions, models = prepar_output(test_df)

# %%
predictions.head()
# Out:
#             timestamp    month
# 0 2025-01-01 00:00:00  2025-01
# 1 2025-01-01 01:00:00  2025-01
# 2 2025-01-01 02:00:00  2025-01
# 3 2025-01-01 03:00:00  2025-01
# 4 2025-01-01 04:00:00  2025-01

# %%
def training_model(train_df, test_df):
    # Train separate models for each hour ahead
    for h in range(1, 7):
        y_train = train_df[f'target_{h}']

        # Train XGBoost model for h-hour ahead forecast
        model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
        model.fit(X_train, y_train)

        # Store model
        models[h] = model

        # Predict for test set
        predictions[f"{h}_hour_ahead"] = model.predict(X_test_eval)

#     predictions['target'] = np.where(test_df['energy_output'] == 0, 1, test_df['energy_output'])

    test_df["energy_output"] = np.where(test_df['energy_output'] == 0, 1, test_df['energy_output'])
    return predictions, test_df

predictions, test_df = training_model(train_df, test_df)

# %%
predictions.head()
# Out:
#             timestamp    month  1_hour_ahead  2_hour_ahead  3_hour_ahead  \
# 0 2025-01-01 00:00:00  2025-01      13031.87      29131.57      43039.71
# 1 2025-01-01 01:00:00  2025-01      13031.87      29131.57      43035.98
# 2 2025-01-01 02:00:00  2025-01      12311.60      29977.55      42804.07
# 3 2025-01-01 03:00:00  2025-01      12311.60      29977.55      42804.07
# 4 2025-01-01 04:00:00  2025-01      12311.60      29977.55      42804.07
#
#    4_hour_ahead  5_hour_ahead  6_hour_ahead
# 0      43026.20       5632.76       8742.29
# 1      39517.90       5632.76       8742.29
# 2      39517.90      15556.57      10523.07
# 3      39517.90      15556.57      10523.07
# 4      39517.90      15556.57      10523.07

# %%
def get_hourly_MAPE(test_df, predictions):
    # Compute MAPE for each forecast horizon
    for h in range(1, 7):
        predictions[f"MAPE_{h}_hour_ahead"] = mean_absolute_percentage_error(test_df["energy_output"].fillna(1), predictions[f"{h}_hour_ahead"])
    return predictions
predictions = get_hourly_MAPE(test_df, predictions)

# %%
def get_monthly_mape(predictions):
    # Calculate Monthly Average MAPE (expanded format)
    monthly_mape = predictions.groupby("month")[[f"MAPE_{h}_hour_ahead" for h in range(1, 7)]].mean()
    return monthly_mape

monthly_mape = get_monthly_mape(predictions)

# %%
monthly_mape.head()
# Out:
#          MAPE_1_hour_ahead  MAPE_2_hour_ahead  MAPE_3_hour_ahead  \
# month
# 2025-01           17304.76           15057.56           21797.27
# 2025-02           17304.76           15057.56           21797.27
#
#          MAPE_4_hour_ahead  MAPE_5_hour_ahead  MAPE_6_hour_ahead
# month
# 2025-01           20763.83            5128.02            4741.30
# 2025-02           20763.83            5128.02            4741.30

# %%
# Save results
predictions.to_csv("multi_step_forecast.csv", index=False)
monthly_mape.to_csv("monthly_mape_results.csv", index=True)

# %%
monthly_mape.head()
# Out:
#          MAPE_1_hour_ahead  MAPE_2_hour_ahead  MAPE_3_hour_ahead  \
# month
# 2025-01           17304.76           15057.56           21797.27
# 2025-02           17304.76           15057.56           21797.27
#
#          MAPE_4_hour_ahead  MAPE_5_hour_ahead  MAPE_6_hour_ahead
# month
# 2025-01           20763.83            5128.02            4741.30
# 2025-02           20763.83            5128.02            4741.30

# %%
predictions.head()
# Out:
#             timestamp    month  1_hour_ahead  2_hour_ahead  3_hour_ahead  \
# 0 2025-01-01 00:00:00  2025-01      13031.87      29131.57      43039.71
# 1 2025-01-01 01:00:00  2025-01      13031.87      29131.57      43035.98
# 2 2025-01-01 02:00:00  2025-01      12311.60      29977.55      42804.07
# 3 2025-01-01 03:00:00  2025-01      12311.60      29977.55      42804.07
# 4 2025-01-01 04:00:00  2025-01      12311.60      29977.55      42804.07
#
#    4_hour_ahead  5_hour_ahead  6_hour_ahead  MAPE_1_hour_ahead  \
# 0      43026.20       5632.76       8742.29           17304.76
# 1      39517.90       5632.76       8742.29           17304.76
# 2      39517.90      15556.57      10523.07           17304.76
# 3      39517.90      15556.57      10523.07           17304.76
# 4      39517.90      15556.57      10523.07           17304.76
#
#    MAPE_2_hour_ahead  MAPE_3_hour_ahead  MAPE_4_hour_ahead  MAPE_5_hour_ahead  \
# 0           15057.56           21797.27           20763.83            5128.02
# 1           15057.56           21797.27           20763.83            5128.02
# 2           15057.56           21797.27           20763.83            5128.02
# 3           15057.56           21797.27           20763.83            5128.02
# 4           15057.56           21797.27           20763.83            5128.02
#
#    MAPE_6_hour_ahead
# 0            4741.30
# 1            4741.30
# 2            4741.30
# 3            4741.30
# 4            4741.30
